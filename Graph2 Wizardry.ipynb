# %%
import wizardry.graph2

# %%
graph = wizardry.graph2()
n = graph.node

# %%
with graph:
    n("a") > n("b")
    n("a") > n("c")

# %%
print(graph)
# Out:
# digraph {
# 	a
# 	b
# 		a -> b
# 	a
# 	c
# 		a -> c
# }

# %%
graph.draw()

# %%
n("b") > n("a")
# Out:
# False

# %%
with graph:
    n("c") < n("z")
    n("z") == n("5")

# %%
n("a") == n("b")
# Out:
# False

# %%
graph.draw()

# %%
print(graph)
# Out:
# digraph {
# 	a
# 	b
# 		a -> b
# 	a
# 	c
# 		a -> c
# 	b
# 	a
# 	c
# 	z
# 		z -> c
# 	z
# 	5
# 		z -> 5
# 		5 -> z
# }
