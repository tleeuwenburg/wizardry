# %%
import wizardry.graph

# %%
graph = wizardry.graph()
n = graph.node

# %%
with graph:
    n("a") > n("b")
    n("a") > n("c")

# %%
graph.draw()

# %%
n("b") < n("a")
# Out:
# True

# %%
n("b") > n("a")
# Out:
# False

# %%
with graph:
    n("c") < n("z")
    n("z") == n("5")

# %%
n("a") == n("b")
# Out:
# False

# %%
graph.draw()
